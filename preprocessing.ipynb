# %% [markdown]
# # Sequence assembly tutorial
# ---
# ECV-Leuven

# %% [markdown]
# ## Objectives
# Upon completion of this exercise, you will be able to:
#
# •	understand the basics of de novo sequence assembly
#
# •	use various methods / programs to validate assembly results
#
# ## Background
# Multiple patients came into the hospital with a variety of symptoms, assay’s weren’t able to determine the pathogen with certainty. As a solution the hospital used metagenomic sequencing to identify the pathogen.
#
# In this study, 6 viral metagenomic sequencing paired read datasets were collected. The goal of this exercise is to assemble the genome and identify the pathogen.

# %%
conda config --add envs_dirs ./bin 
mamba create -n dev -y -c bioconda fastqc fastp kraken2 spades bowtie2 blast
conda activate dev
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.27.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# ...

# %% [markdown]
# ## Ideal workflow of a pipeline
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # Pre-processing
# ## QC - FASTQ
# 1.	Data pre-processing
#
# 1.1	Examine the file format and contents
#
# 1.1.1	Choose an appropriate tool:
# Do you want to open the file directly?
#
#
# 1.1.2	Review the results:
# 1.1.2.1	What is the basic structure of the fastq format? How does it differ from the fasta format?
#
#
#
# 1.1.2.2	What is the length for the first sequence read in the fastq file?
#
#
# 1.2	Evaluate and improve the quality of the sequence reads

# %%
# mkdir - make directory
mkdir fastq_raw

# %%
fastq --version

# %% [markdown]
# ## Trimming - Fastp & FASTQ
# Examine the report again, what has changed?
# How many reads are there? Did there size change? What's the average quality of the basepairs, has it improved?

# %%
mkdir fastp

# %%
fastp --version

# %% [markdown]
# ## Host removal - Bowtie2
# Why do we do this? How do we do this? How does Bowtie2 work - what is read mapping?  Which hosts do we use?

# %%
wget https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/homo_sapiens/genome/genome.fasta

# %%
bowtie2 --version

# %% [markdown]
# ## Sample diversity exploration - Kraken2
# Why do we do this? How do we do this? How does Kraken2 work?

# %%
kraken2 --version
# Out:
# Failed to start the Kernel.
#
# Failed to start the Kernel 'Bash'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Activating base to run Jupyter failed with function toString() { [native code] }

# %% [markdown]
# Download the kraken2 DB:

# %%
mkdir -p databases/kraken2; cd databases/kraken2
wget https://genome-idx.s3.amazonaws.com/kraken/k2_viral_20230314.tar.gz

# %%
tar -xvf k2_viral_20230314.tar.gz; rm test.tar.gz

cd ../../
